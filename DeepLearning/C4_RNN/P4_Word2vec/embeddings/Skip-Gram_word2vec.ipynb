# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
# 额，总得来说就是对数据修整
# 符号转化，删除低频词汇
# 按出现频率构建字典
# 使用subsampling随机剔除样本(出现频率越高，被剔除率越大)
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
greqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1-np.sqrt(threshold/greqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# train_words = # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6683 0.3914 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5834 0.3917 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5400 0.3806 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5881 0.3818 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4995 0.3828 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5288 0.3825 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5811 0.3819 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5520 0.3817 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4963 0.3860 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4541 0.3870 sec/batch
# Nearest to and: dobson, seabury, mumonkan, combinatorial, proportionally, gunner, colletti, himachal,
# Nearest to with: intern, mini, eutheria, luft, suzerain, ak, restatement, matrimonial,
# Nearest to at: restricted, semester, lucius, lauderdale, avant, saterland, rundown, abdallah,
# Nearest to five: hermetical, critically, candace, simenon, gamble, soundtrack, id, judge,
# Nearest to also: obe, vicinity, transcendentalism, lethality, cookbook, saurischia, structuralism, amplify,
# Nearest to than: nachrichten, browser, hamilton, despots, stumble, newport, school, foundations,
# Nearest to all: sparingly, raked, herman, jfs, celluloid, leland, chris, homeomorphisms,
# Nearest to there: fonni, gala, horta, earned, docs, moqed, turkle, recalcitrant,
# Nearest to running: reversals, beazley, bmj, iliad, source, cardboard, electrodynamic, teapot,
# Nearest to applied: dissociatives, acknowledging, esk, fredric, histone, blossom, vasquez, gardens,
# Nearest to taking: hominids, tori, ctor, alicante, dredged, screenonline, bagoas, spoofing,
# Nearest to know: konstantin, adema, triode, innsbruck, dominatrixes, tokyopop, raisins, regan,
# Nearest to universe: maranh, plebs, iroquois, generis, saimei, jiro, croatians, swat,
# Nearest to prince: serber, cumming, westphalian, slaughterhouse, rosicrucian, vacuoles, porpoises, dis,
# Nearest to consists: wembley, blaylock, tito, patched, vibrio, auxerre, astroturf, fedex,
# Nearest to account: equuleus, nectar, rumen, lamp, dreyer, marle, caenorhabditis, subclasses,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5025 0.4067 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4288 0.4027 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3316 0.3922 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2715 0.3933 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2257 0.3913 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1873 0.4168 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1257 0.4012 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0681 0.4030 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0372 0.4039 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9793 0.3997 sec/batch
# Nearest to and: distinguished, framework, may, quote, dobson, proportionally, seabury, concise,
# Nearest to with: senses, intern, mini, danger, implemented, origins, signify, much,
# Nearest to at: restricted, semester, lauderdale, own, alphabetical, avant, spelling, early,
# Nearest to five: critically, soundtrack, hermetical, gamble, refrain, judge, sporadic, molecules,
# Nearest to also: vicinity, transcendentalism, obe, new, harvesting, lethality, divided, cooperate,
# Nearest to than: browser, nachrichten, school, officially, hamilton, undergraduate, buildings, despots,
# Nearest to all: sparingly, raked, herman, came, chris, vietnamese, drawn, suggested,
# Nearest to there: earned, elements, genre, related, gala, philharmonic, recalcitrant, ran,
# Nearest to running: reversals, source, governmental, beazley, cardboard, iliad, liaisons, telomeres,
# Nearest to applied: dissociatives, acknowledging, gardens, esk, since, blossom, comes, vasquez,
# Nearest to taking: hominids, dredged, tori, ctor, conventional, alicante, screenonline, levees,
# Nearest to know: needs, cbm, triode, maharashtra, dominatrixes, konstantin, tokyopop, innsbruck,
# Nearest to universe: plebs, few, maranh, algebras, iroquois, croatians, saimei, jiro,
# Nearest to prince: serber, cumming, slaughterhouse, order, westphalian, rosicrucian, giantesses, terminals,
# Nearest to consists: mapping, wembley, trout, patched, khrushchev, democratic, tito, has,
# Nearest to account: caenorhabditis, dreyer, espy, wallace, lamp, smyrnaeans, lai, parlour,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9606 0.4011 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9069 0.4074 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9001 0.3982 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8707 0.4058 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8244 0.3923 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8285 0.4046 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8184 0.3992 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8020 0.4077 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8048 0.3985 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7903 0.3954 sec/batch
# Nearest to and: constituted, dobson, visualization, obscure, framework, proportionally, distinguished, quote,
# Nearest to with: intern, senses, signify, mini, privilege, origins, declassified, luft,
# Nearest to at: restricted, semester, avant, lauderdale, prevailing, lucius, spelling, animated,
# Nearest to five: critically, refrain, gamble, editor, sporadic, soundtrack, hermetical, glossolalia,
# Nearest to also: vicinity, transcendentalism, obe, amplify, indoors, lethality, harvesting, cookbook,
# Nearest to than: browser, hamilton, outcome, foundations, despots, nachrichten, simpsons, undergraduate,
# Nearest to all: sparingly, chris, raked, herman, came, vietnamese, celluloid, drawn,
# Nearest to there: earned, genre, elements, compelled, clerical, recalcitrant, ran, philharmonic,
# Nearest to running: source, reversals, governmental, iliad, cardboard, beazley, liaisons, litres,
# Nearest to applied: acknowledging, fredric, blossom, dissociatives, vasquez, esk, bum, since,
# Nearest to taking: hominids, tori, dredged, screenonline, ctor, alicante, conventional, riddles,
# Nearest to know: needs, konstantin, loud, cbm, maharashtra, triode, tokyopop, innsbruck,
# Nearest to universe: plebs, iroquois, maranh, algebras, probabilities, few, pipes, generis,
# Nearest to prince: serber, rosicrucian, slaughterhouse, kernel, cumming, order, giantesses, centimeters,
# Nearest to consists: wembley, mapping, patched, diametrically, democratic, trout, tito, khrushchev,
# Nearest to account: wallace, espy, caenorhabditis, lamp, repression, troubled, dreyer, smyrnaeans,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7841 0.4022 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7642 0.3959 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7317 0.4036 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7018 0.3910 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7597 0.3913 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6818 0.3951 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7034 0.3864 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7166 0.3860 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7002 0.3916 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6656 0.3837 sec/batch
# Nearest to and: dobson, obscure, constituted, visualization, jacobite, irritability, mumonkan, gunner,
# Nearest to with: intern, senses, signify, privilege, origins, luft, approved, kicked,
# Nearest to at: semester, restricted, avant, lucius, lauderdale, prevailing, casually, procession,
# Nearest to five: singer, seven, two, sporadic, editor, three, gamble, critically,
# Nearest to also: vicinity, transcendentalism, obe, indoors, amplify, cookbook, lethality, structuralism,
# Nearest to than: browser, outcome, despots, nachrichten, foundations, brush, hamilton, roofs,
# Nearest to all: sparingly, chris, raked, came, vietnamese, celluloid, serie, leland,
# Nearest to there: genre, elements, fonni, compelled, clerical, recalcitrant, earned, docs,
# Nearest to running: source, reversals, governmental, cardboard, iliad, beazley, bmj, commissioner,
# Nearest to applied: acknowledging, fredric, esk, dissociatives, blossom, bum, vasquez, treating,
# Nearest to taking: tori, hominids, screenonline, dredged, harmonious, ctor, alicante, tvs,
# Nearest to know: needs, loud, konstantin, cbm, loyalist, maharashtra, tokyopop, dominatrixes,
# Nearest to universe: iroquois, plebs, maranh, generis, algebras, probabilities, jiro, croatians,
# Nearest to prince: slaughterhouse, rosicrucian, serber, westphalian, giantesses, cumming, centimeters, levinson,
# Nearest to consists: mapping, wembley, diametrically, patched, trout, natchez, kaaba, pershing,
# Nearest to account: dreyer, espy, equalled, wallace, smyrnaeans, caenorhabditis, parlour, lamp,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6689 0.3890 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6722 0.3909 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6306 0.3896 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6299 0.3922 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6784 0.3945 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6407 0.3984 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6027 0.2818 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5421 0.3909 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5213 0.4082 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5245 0.3952 sec/batch
# Nearest to and: dobson, constituted, visualization, irritability, mumonkan, willingly, obscure, gunner,
# Nearest to with: intern, senses, luft, origins, signify, privilege, suzerain, elevators,
# Nearest to at: semester, lucius, restricted, lauderdale, prevailing, casually, avant, courthouse,
# Nearest to five: singer, seven, two, three, one, editor, sporadic, critically,
# Nearest to also: vicinity, transcendentalism, amplify, lethality, obe, structuralism, synonymously, harvesting,
# Nearest to than: browser, brush, despots, roofs, nachrichten, foundations, outcome, pigs,
# Nearest to all: sparingly, serie, gmt, chris, sandstone, raked, vietnamese, intelligentsia,
# Nearest to there: elements, fonni, recalcitrant, milking, genre, survival, related, lexical,
# Nearest to running: source, reversals, bmj, governmental, beazley, cardboard, electrodynamic, iliad,
# Nearest to applied: fredric, esk, acknowledging, dissociatives, blossom, bum, treating, be,
# Nearest to taking: tori, hominids, dredged, ctor, screenonline, alicante, spoofing, tvs,
# Nearest to know: needs, konstantin, dominatrixes, maharashtra, loud, loyalist, tokyopop, eden,
# Nearest to universe: iroquois, generis, maranh, plebs, probabilities, algebras, croatians, jiro,
# Nearest to prince: slaughterhouse, westphalian, four, rosicrucian, viii, hosea, serber, harpercollins,
# Nearest to consists: mapping, wembley, kaaba, patched, diametrically, democratic, pershing, natchez,
# Nearest to account: espy, dreyer, smyrnaeans, equalled, caenorhabditis, lai, wallace, marle,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4972 0.4046 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4919 0.3976 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4838 0.3941 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5232 0.3954 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4826 0.3935 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4867 0.3902 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4468 0.3849 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4200 0.3848 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4085 0.3889 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4300 0.3878 sec/batch
# Nearest to and: constituted, willingly, irritability, mumonkan, withstood, obscure, proportionally, criminalised,
# Nearest to with: intern, senses, luft, suzerain, origins, wapping, elevators, declassified,
# Nearest to at: semester, lucius, restricted, lauderdale, avant, procession, prevailing, courthouse,
# Nearest to five: seven, two, editor, three, highways, glossolalia, singer, unpaved,
# Nearest to also: vicinity, transcendentalism, lethality, amplify, structuralism, obe, marys, synonymously,
# Nearest to than: browser, brush, roofs, despots, nachrichten, inner, outcome, trout,
# Nearest to all: sparingly, gmt, identify, xsl, raked, sandstone, serie, frac,
# Nearest to there: fonni, related, recalcitrant, elements, milking, genre, compelled, hereditary,
# Nearest to running: source, reversals, bmj, beazley, cardboard, commissioner, cyan, electrodynamic,
# Nearest to applied: fredric, acknowledging, esk, treating, be, bum, exptime, risings,
# Nearest to taking: tori, hominids, screenonline, ctor, alicante, spoofing, kamchatka, dredged,
# Nearest to know: needs, abracadabra, dominatrixes, eden, maharashtra, regan, loud, triode,
# Nearest to universe: generis, iroquois, probabilities, algebras, maranh, jiro, plebs, ddd,
# Nearest to prince: slaughterhouse, viii, rosicrucian, hosea, westphalian, four, wife, harpercollins,
# Nearest to consists: mapping, kaaba, pershing, diametrically, congreso, patched, wembley, democratic,
# Nearest to account: smyrnaeans, dreyer, espy, nectar, edging, equalled, caenorhabditis, marksman,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4312 0.3925 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4217 0.3889 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4134 0.3873 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3838 0.3906 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4057 0.3850 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4338 0.3874 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4074 0.3891 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3855 0.3867 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4124 0.3879 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3934 0.3880 sec/batch
# Nearest to and: mumonkan, criminalised, irritability, proportionally, jacobite, distinguished, obscure, withstood,
# Nearest to with: luft, intern, senses, wapping, advertised, elevators, suzerain, declassified,
# Nearest to at: semester, lucius, avant, casually, restricted, procession, lauderdale, savona,
# Nearest to five: seven, two, one, three, editor, highways, singer, glossolalia,
# Nearest to also: vicinity, lethality, transcendentalism, marys, amplify, indoors, apex, synonymously,
# Nearest to than: roofs, brush, inner, browser, nachrichten, canetti, pigs, normal,
# Nearest to all: sparingly, gmt, identify, corresponding, xsl, sandstone, frac, empirical,
# Nearest to there: recalcitrant, fonni, milking, compelled, related, atheistic, elements, biomes,
# Nearest to running: source, reversals, cardboard, bmj, commissioner, beazley, speed, cyan,
# Nearest to applied: fredric, acknowledging, exptime, esk, treating, risings, infielders, vasquez,
# Nearest to taking: tori, hominids, spoofing, screenonline, kamchatka, dredged, alicante, ctor,
# Nearest to know: needs, dominatrixes, abracadabra, loud, eden, regan, maharashtra, stewie,
# Nearest to universe: probabilities, generis, algebras, maranh, jiro, iroquois, plebs, croatians,
# Nearest to prince: viii, hosea, slaughterhouse, wife, eldest, rosicrucian, died, westphalian,
# Nearest to consists: mapping, democratic, congreso, kaaba, danville, diametrically, wembley, pershing,
# Nearest to account: smyrnaeans, nectar, dreyer, caenorhabditis, edging, espy, marle, suspicions,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3677 0.3899 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3756 0.3921 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3326 0.3876 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3914 0.3880 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3913 0.3888 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3774 0.3910 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3888 0.3931 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3778 0.3887 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3527 0.3898 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3393 0.3878 sec/batch
# Nearest to and: predominant, ideologies, criminalised, constituted, withstood, proportionally, distinguished, mumonkan,
# Nearest to with: intern, luft, senses, origins, suzerain, advertised, elevators, wapping,
# Nearest to at: semester, procession, lucius, avant, casually, restricted, savona, prevailing,
# Nearest to five: seven, two, three, one, highways, unpaved, four, editor,
# Nearest to also: vicinity, transcendentalism, lethality, divided, amplify, marys, synonymously, new,
# Nearest to than: roofs, canetti, inner, trout, brush, normal, woden, nachrichten,
# Nearest to all: sparingly, gmt, identify, corresponding, sandstone, frac, prod, came,
# Nearest to there: related, milking, recalcitrant, compelled, fonni, biomes, fremen, crandall,
# Nearest to running: source, reversals, cardboard, speed, bmj, commissioner, professional, beazley,
# Nearest to applied: fredric, esk, acknowledging, exptime, bum, infielders, deist, leveling,
# Nearest to taking: hominids, tori, spoofing, screenonline, kamchatka, dredged, ctor, duh,
# Nearest to know: needs, abracadabra, dominatrixes, loud, eden, regan, editable, zoramites,
# Nearest to universe: generis, probabilities, maranh, algebras, jiro, berger, plebs, sibm,
# Nearest to prince: viii, hosea, rosicrucian, eldest, died, wife, slaughterhouse, four,
# Nearest to consists: mapping, congreso, democratic, kaaba, pershing, natchez, danville, imagesize,
# Nearest to account: smyrnaeans, nectar, dreyer, suspicions, edging, alchemy, marle, believers,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3539 0.3930 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3160 0.3898 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3911 0.3921 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3816 0.3842 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3824 0.3858 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2987 0.3866 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2974 0.3834 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3405 0.3878 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1980 0.3876 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2953 0.3878 sec/batch
# Nearest to and: proportionally, withstood, predominant, trustee, irritability, distinguished, ideologies, framework,
# Nearest to with: wapping, intern, luft, elevators, writable, suzerain, never, advertised,
# Nearest to at: semester, avant, procession, lucius, casually, labrador, savona, deformities,
# Nearest to five: seven, two, one, three, four, eight, est, unpaved,
# Nearest to also: vicinity, lethality, transcendentalism, synonymously, marys, apex, amplify, divided,
# Nearest to than: roofs, inner, canetti, hips, normal, pigs, blazon, trout,
# Nearest to all: sparingly, gmt, frac, prod, corresponding, identify, serie, xsl,
# Nearest to there: related, milking, fonni, recalcitrant, biomes, charlatans, atheistic, compelled,
# Nearest to running: source, cardboard, reversals, commissioner, professional, bmj, speed, wont,
# Nearest to applied: fredric, acknowledging, esk, exptime, deist, bum, relativism, infielders,
# Nearest to taking: tori, hominids, spoofing, kamchatka, dredged, ctor, emanated, alicante,
# Nearest to know: eden, dominatrixes, loud, editable, regan, abracadabra, needs, injunctions,
# Nearest to universe: generis, probabilities, maranh, algebras, jiro, sibm, berger, behaviours,
# Nearest to prince: viii, hosea, rosicrucian, slaughterhouse, westphalian, eldest, france, died,
# Nearest to consists: mapping, congreso, democratic, kaaba, pershing, imagesize, danville, travels,
# Nearest to account: nectar, smyrnaeans, dreyer, suspicions, marksman, edging, alchemy, tswana,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2732 0.3876 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3170 0.3883 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3254 0.1784 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2510 0.3886 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2471 0.3888 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2077 0.3908 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2239 0.3865 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1901 0.3860 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2257 0.3881 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1878 0.3868 sec/batch
# Nearest to and: trustee, proportionally, predominant, withstood, jacobite, trumps, bulletins, practised,
# Nearest to with: wapping, writable, suzerain, mini, vectoring, intern, elevators, luft,
# Nearest to at: semester, avant, procession, lucius, casually, robed, lauderdale, savona,
# Nearest to five: seven, two, one, three, four, est, eight, highways,
# Nearest to also: vicinity, marys, apex, new, synonymously, lethality, transcendentalism, farmland,
# Nearest to than: officially, roofs, blazon, woden, pigs, inner, trout, hips,
# Nearest to all: sparingly, prod, gmt, nominally, frac, lyceum, corresponding, identify,
# Nearest to there: fonni, related, milking, biomes, compelled, atheists, charlatans, atheistic,
# Nearest to running: cardboard, source, reversals, speed, professional, ste, xbox, commissioner,
# Nearest to applied: acknowledging, fredric, esk, exptime, relativism, deist, transversal, bum,
# Nearest to taking: tori, hominids, spoofing, kamchatka, duh, razed, oysters, bagoas,
# Nearest to know: dominatrixes, regan, abracadabra, loud, editable, eden, bentine, stewie,
# Nearest to universe: generis, probabilities, jiro, maranh, sibm, berger, algebras, overcoming,
# Nearest to prince: viii, hosea, rosicrucian, wife, westphalian, slaughterhouse, giantesses, died,
# Nearest to consists: congreso, mapping, pershing, democratic, adjacent, auxerre, kaaba, imagesize,
# Nearest to account: nectar, smyrnaeans, suspicions, alchemy, dreyer, marksman, decalogue, edging,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2495 0.3902 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2185 0.3861 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2216 0.3873 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1510 0.3841 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1621 0.3821 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1503 0.3893 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1598 0.3873 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1835 0.3889 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2007 0.3902 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1919 0.3839 sec/batch
# Nearest to and: predominant, withstood, jacobite, practised, mumonkan, proportionally, distinguished, may,
# Nearest to with: wapping, writable, luft, elevators, vectoring, intern, grille, weight,
# Nearest to at: semester, procession, lucius, robed, savona, avant, casually, consented,
# Nearest to five: two, seven, one, three, four, eight, est, highways,
# Nearest to also: vicinity, marys, synonymously, lethality, sensitive, apex, transcendentalism, new,
# Nearest to than: hips, blazon, roofs, officially, inner, pigs, trout, normal,
# Nearest to all: sparingly, gmt, prod, frac, corresponding, lyceum, identify, xsl,
# Nearest to there: fonni, milking, related, biomes, compelled, atheists, clerical, atheistic,
# Nearest to running: cardboard, source, speed, reversals, professional, cyan, door, isuzu,
# Nearest to applied: acknowledging, exptime, fredric, esk, deist, transversal, relativism, hoses,
# Nearest to taking: tori, hominids, spoofing, bagoas, kamchatka, duh, oysters, emanated,
# Nearest to know: dominatrixes, abracadabra, editable, loud, you, regan, please, gbase,
# Nearest to universe: probabilities, maranh, jiro, generis, berger, sibm, overcoming, bmws,
# Nearest to prince: viii, hosea, rosicrucian, slaughterhouse, giantesses, westphalian, wife, died,
# Nearest to consists: mapping, congreso, adjacent, annex, auxerre, kaaba, pershing, democratic,
# Nearest to account: smyrnaeans, nectar, suspicions, decalogue, alchemy, dreyer, immanent, subclasses,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1758 0.3875 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2170 0.3870 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1806 0.3870 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1552 0.3875 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1856 0.3874 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1955 0.3860 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1863 0.3833 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1516 0.3851 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1607 0.3881 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1836 0.3871 sec/batch
# Nearest to and: predominant, mumonkan, ideologies, withstood, proportionally, criminalised, distinguished, bulletins,
# Nearest to with: writable, luft, goalkeeper, intern, wapping, puisne, suzerain, vectoring,
# Nearest to at: semester, procession, lucius, avant, consented, bernoulli, labrador, casually,
# Nearest to five: two, seven, one, three, four, eight, est, population,
# Nearest to also: marys, vicinity, uffizi, synonymously, apex, lethality, famille, new,
# Nearest to than: hips, blazon, inner, roofs, trout, officially, foreground, canetti,
# Nearest to all: sparingly, prod, identify, gmt, corresponding, nominally, declare, lyceum,
# Nearest to there: milking, atheists, related, fonni, morphophonemic, atheistic, hurling, with,
# Nearest to running: cardboard, reversals, source, door, isuzu, ste, wont, speed,
# Nearest to applied: acknowledging, exptime, fredric, deist, relativism, esk, transversal, inductors,
# Nearest to taking: tori, hominids, spoofing, bagoas, duh, emanated, oysters, psychosomatic,
# Nearest to know: you, bentine, dominatrixes, loud, abracadabra, editable, please, gbase,
# Nearest to universe: probabilities, maranh, jiro, generis, berger, sibm, bmws, discovered,
# Nearest to prince: viii, hosea, giantesses, slaughterhouse, eldest, rosicrucian, order, westphalian,
# Nearest to consists: congreso, mapping, auxerre, kaaba, adjacent, imagesize, annex, democratic,
# Nearest to account: nectar, smyrnaeans, suspicions, dreyer, alchemy, decalogue, immanent, subclasses,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1980 0.3880 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1982 0.3858 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1787 0.3866 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2006 0.3880 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1458 0.3878 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1216 0.3868 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1626 0.3876 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1193 0.3901 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1931 0.3888 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2182 0.3879 sec/batch
# Nearest to and: jacobite, withstood, ideologies, practised, mumonkan, predominant, lordship, was,
# Nearest to with: never, goalkeeper, intern, luft, puisne, suzerain, scandalous, writable,
# Nearest to at: semester, procession, lucius, avant, labrador, attended, consented, in,
# Nearest to five: seven, one, two, three, four, eight, six, est,
# Nearest to also: marys, barony, new, lethality, vicinity, uffizi, synonymously, mention,
# Nearest to than: blazon, officially, hips, roofs, unfit, outcome, undertaking, woden,
# Nearest to all: sparingly, serie, prod, lyceum, gmt, declare, identify, munic,
# Nearest to there: milking, fonni, clerical, atheistic, charlatans, recalcitrant, atheists, compelled,
# Nearest to running: cardboard, ste, isuzu, reversals, wont, beazley, willis, door,
# Nearest to applied: acknowledging, fredric, deist, exptime, relativism, esk, inductors, transversal,
# Nearest to taking: tori, hominids, spoofing, emanated, duh, bagoas, psychosomatic, renounce,
# Nearest to know: you, dominatrixes, editable, bentine, loud, please, abracadabra, gbase,
# Nearest to universe: maranh, probabilities, berger, bmws, sibm, jiro, generis, discovered,
# Nearest to prince: viii, hosea, order, rosicrucian, eldest, slaughterhouse, giantesses, westphalian,
# Nearest to consists: congreso, mapping, adjacent, annex, imagesize, auxerre, kaaba, natchez,
# Nearest to account: smyrnaeans, nectar, suspicions, decalogue, dreyer, alchemy, immanent, nyc,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2225 0.3912 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1305 0.3900 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1488 0.3861 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1396 0.3872 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0491 0.3894 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1594 0.3876 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1405 0.3893 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1648 0.3886 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1812 0.0737 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0865 0.3893 sec/batch
# Nearest to and: withstood, framework, predominant, irritability, bumbling, ih, mindat, proportionally,
# Nearest to with: writable, vectoring, never, suzerain, grille, wapping, intern, expire,
# Nearest to at: semester, procession, robed, attended, hundred, chill, lucius, avant,
# Nearest to five: seven, two, one, three, four, eight, est, six,
# Nearest to also: marys, new, vicinity, synonymously, famille, uffizi, farmland, barony,
# Nearest to than: blazon, hips, officially, roofs, costs, formatted, unfit, undertaking,
# Nearest to all: sparingly, lyceum, prod, identify, serie, boundaries, gmt, in,
# Nearest to there: milking, fonni, with, currently, metropolitan, atheists, charlatans, bosniaks,
# Nearest to running: cardboard, reversals, door, isuzu, modifications, rajya, ste, supercomputers,
# Nearest to applied: fredric, exptime, acknowledging, relativism, inductors, deist, transversal, esk,
# Nearest to taking: hominids, spoofing, tori, bagoas, duh, evasion, emanated, humiliation,
# Nearest to know: you, dominatrixes, bentine, editable, we, please, stewie, loud,
# Nearest to universe: maranh, probabilities, sibm, berger, generis, hermeneutics, jiro, discovered,
# Nearest to prince: viii, hosea, slaughterhouse, eldest, order, giantesses, rosicrucian, westphalian,
# Nearest to consists: congreso, mapping, adjacent, annex, imagesize, democratic, danville, entities,
# Nearest to account: nectar, smyrnaeans, suspicions, alchemy, dreyer, decalogue, nyc, macpherson,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0673 0.3931 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0950 0.3890 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1006 0.3894 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0682 0.3896 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0672 0.3894 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0405 0.3890 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1084 0.3860 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0729 0.3877 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1257 0.3883 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0256 0.3884 sec/batch
# Nearest to and: withstood, framework, bumbling, homicides, fishman, the, villagers, gap,
# Nearest to with: writable, vectoring, wapping, never, su, grille, there, goalkeeper,
# Nearest to at: semester, procession, chill, robed, lucius, attended, hundred, undertaking,
# Nearest to five: seven, two, one, three, four, eight, six, est,
# Nearest to also: marys, new, vicinity, uffizi, barony, famille, farmland, lethality,
# Nearest to than: hips, blazon, their, undertaking, soak, roofs, officially, costs,
# Nearest to all: sparingly, in, lyceum, prod, serie, identify, gmt, boundaries,
# Nearest to there: milking, fonni, with, engrailed, clerical, currently, atheists, charlatans,
# Nearest to running: cardboard, door, isuzu, ste, rajya, reversals, modifications, supercomputers,
# Nearest to applied: fredric, acknowledging, exptime, inductors, relativism, deist, esk, transversal,
# Nearest to taking: tori, hominids, humiliation, spoofing, bagoas, razed, zealander, emanated,
# Nearest to know: you, dominatrixes, we, abracadabra, bentine, editable, needs, please,
# Nearest to universe: maranh, probabilities, berger, sibm, generis, stellar, hermeneutics, bmws,
# Nearest to prince: viii, order, giantesses, hosea, eldest, slaughterhouse, subdued, rosicrucian,
# Nearest to consists: congreso, mapping, adjacent, annex, imagesize, entities, danville, auxerre,
# Nearest to account: nectar, smyrnaeans, suspicions, decalogue, alchemy, edging, dreyer, saboteur,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0281 0.3938 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0418 0.3877 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0170 0.3882 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0545 0.3890 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0739 0.3896 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0748 0.3891 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0545 0.3899 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0929 0.3860 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0491 0.3889 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0559 0.3891 sec/batch
# Nearest to and: withstood, framework, uml, irritability, gap, ddr, bulletins, predominant,
# Nearest to with: writable, there, vectoring, luft, flammable, su, never, guppy,
# Nearest to at: semester, procession, robed, chill, attended, hundred, undertaking, consented,
# Nearest to five: two, seven, one, three, four, eight, six, zero,
# Nearest to also: marys, sensitive, barony, lethality, synonymously, new, famille, positive,
# Nearest to than: blazon, hips, undertaking, their, officially, soak, costs, formatted,
# Nearest to all: sparingly, in, identify, prod, declare, substitutions, corresponding, lyceum,
# Nearest to there: milking, with, clerical, fonni, engrailed, geocaches, recalcitrant, atheists,
# Nearest to running: cardboard, door, isuzu, ste, modifications, rajya, supercomputers, reversals,
# Nearest to applied: fredric, exptime, inductors, acknowledging, relativism, deist, halides, devlin,
# Nearest to taking: tori, hominids, zealander, spoofing, humiliation, bagoas, emanated, razed,
# Nearest to know: you, we, dominatrixes, abracadabra, bentine, gbase, if, editable,
# Nearest to universe: maranh, probabilities, berger, sibm, generis, world, jiro, hermeneutics,
# Nearest to prince: viii, order, giantesses, hosea, eldest, slaughterhouse, fiorentino, rosicrucian,
# Nearest to consists: congreso, mapping, adjacent, annex, imagesize, entities, danville, democratic,
# Nearest to account: nectar, smyrnaeans, suspicions, decalogue, alchemy, immanent, lai, nyc,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0503 0.3901 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1082 0.3928 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0771 0.3896 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0501 0.3885 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0571 0.3903 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0508 0.3919 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0747 0.3891 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0529 0.3901 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1016 0.3893 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0750 0.3903 sec/batch
# Nearest to and: the, withstood, eastern, practised, in, repudiate, perfumery, of,
# Nearest to with: goalkeeper, never, there, writable, intervened, suzerain, however, scandalous,
# Nearest to at: semester, procession, hundred, attended, enamoured, lucius, undertaking, chill,
# Nearest to five: seven, two, one, three, four, eight, six, zero,
# Nearest to also: barony, new, uffizi, synonymously, marys, famille, vicinity, tempel,
# Nearest to than: blazon, hips, their, officially, undertaking, outcome, foreground, roofs,
# Nearest to all: sparingly, in, identify, declare, serie, lyceum, boundaries, eventual,
# Nearest to there: milking, with, recalcitrant, clerical, atheistic, excerpted, fonni, engrailed,
# Nearest to running: cardboard, isuzu, ste, door, rajya, supercomputers, willis, regrouped,
# Nearest to applied: fredric, inductors, acknowledging, exptime, relativism, deist, halides, rhesus,
# Nearest to taking: zealander, tori, humiliation, hominids, beaten, spoofing, duh, bagoas,
# Nearest to know: you, dominatrixes, we, abracadabra, bentine, gbase, editable, needs,
# Nearest to universe: maranh, berger, world, probabilities, generis, stellar, hermeneutics, bmws,
# Nearest to prince: order, viii, hosea, giantesses, eldest, died, subdued, fiorentino,
# Nearest to consists: congreso, mapping, adjacent, entities, annex, imagesize, nameable, danville,
# Nearest to account: nectar, smyrnaeans, suspicions, decalogue, saboteur, lai, fullness, frankenheimer,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0727 0.3924 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0200 0.3894 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0436 0.3894 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0688 0.3935 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0697 0.3925 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1246 0.3912 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1055 0.3901 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0280 0.3894 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0285 0.3890 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0523 0.3883 sec/batch
# Nearest to and: withstood, eastern, framework, the, doosra, in, practised, ideologies,
# Nearest to with: writable, goalkeeper, never, orlogsflag, there, su, infighting, expire,
# Nearest to at: semester, procession, enamoured, attended, chill, undertaking, avant, robed,
# Nearest to five: one, two, seven, three, four, eight, six, zero,
# Nearest to also: barony, new, famille, marys, uffizi, synonymously, vicinity, lethality,
# Nearest to than: blazon, hips, undertaking, their, costs, soak, exceeding, loaded,
# Nearest to all: sparingly, in, serie, lyceum, prod, substitutions, identify, eventual,
# Nearest to there: milking, recalcitrant, clerical, fonni, with, atheistic, engrailed, peaceable,
# Nearest to running: cardboard, modifications, rajya, ste, door, beazley, isuzu, torvalds,
# Nearest to applied: inductors, fredric, acknowledging, exptime, relativism, halides, deist, rhesus,
# Nearest to taking: zealander, hominids, tori, humiliation, spoofing, emanated, negated, razed,
# Nearest to know: you, we, dominatrixes, editable, please, why, abracadabra, bentine,
# Nearest to universe: maranh, berger, world, probabilities, hermeneutics, generis, stellar, bmws,
# Nearest to prince: order, viii, giantesses, eldest, hosea, fiorentino, westphalian, cond,
# Nearest to consists: congreso, mapping, entities, adjacent, imagesize, nameable, represent, pba,
# Nearest to account: suspicions, smyrnaeans, nectar, saboteur, frankenheimer, lai, decalogue, fullness,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9757 0.3912 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0126 0.3895 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0813 0.3888 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0235 0.3877 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0676 0.3894 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0426 0.3591 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0032 0.3862 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9969 0.3878 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0046 0.3881 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9648 0.3896 sec/batch
# Nearest to and: the, withstood, doosra, eastern, of, in, as, gap,
# Nearest to with: writable, vectoring, suzerain, never, su, intervened, there, expire,
# Nearest to at: semester, procession, attended, enamoured, robed, undertaking, hundred, in,
# Nearest to five: one, two, seven, three, four, eight, six, zero,
# Nearest to also: barony, uffizi, new, synonymously, marys, famille, liepaja, sensitive,
# Nearest to than: blazon, hips, undertaking, their, soak, costs, loaded, formatted,
# Nearest to all: sparingly, lyceum, in, prod, identify, serie, boundaries, eventual,
# Nearest to there: milking, atheistic, fonni, clerical, with, engrailed, recalcitrant, atheists,
# Nearest to running: modifications, cardboard, ste, door, beazley, torvalds, isuzu, rajya,
# Nearest to applied: inductors, fredric, acknowledging, relativism, exptime, deist, halides, rhesus,
# Nearest to taking: zealander, tori, humiliation, hominids, negated, beaten, emanated, razed,
# Nearest to know: you, we, dominatrixes, abracadabra, bentine, please, needs, want,
# Nearest to universe: maranh, world, berger, generis, sibm, hermeneutics, probabilities, bmws,
# Nearest to prince: order, giantesses, viii, hosea, westphalian, fiorentino, eldest, cond,
# Nearest to consists: congreso, mapping, entities, adjacent, nameable, imagesize, pba, represent,
# Nearest to account: suspicions, smyrnaeans, nectar, decalogue, fullness, saboteur, frankenheimer, lai,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9818 0.3915 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9465 0.3874 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0261 0.3860 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0042 0.3867 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0123 0.3898 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9958 0.3929 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9261 0.3938 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9599 0.3887 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9384 0.3863 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9661 0.3857 sec/batch
# Nearest to and: the, of, in, a, withstood, eastern, as, materialize,
# Nearest to with: writable, expire, goalkeeper, flammable, vectoring, su, never, tracks,
# Nearest to at: semester, enamoured, chill, attended, procession, undertaking, hundred, robed,
# Nearest to five: two, one, seven, three, four, eight, six, zero,
# Nearest to also: barony, sensitive, new, synonymously, propositional, famille, marys, lethality,
# Nearest to than: blazon, more, hips, soak, their, are, undertaking, brush,
# Nearest to all: in, sparingly, lyceum, identify, prod, serie, a, declare,
# Nearest to there: milking, fonni, atheistic, number, with, recalcitrant, clerical, engrailed,
# Nearest to running: door, cardboard, modifications, ste, isuzu, beazley, supercomputers, regrouped,
# Nearest to applied: fredric, inductors, acknowledging, relativism, exptime, deist, halides, watercolors,
# Nearest to taking: zealander, humiliation, beaten, tori, negated, razed, oysters, hominids,
# Nearest to know: you, we, dominatrixes, please, bentine, abracadabra, why, thank,
# Nearest to universe: maranh, sibm, berger, probabilities, hermeneutics, world, bmws, generis,
# Nearest to prince: order, giantesses, fiorentino, westphalian, viii, slaughterhouse, subdued, serber,
# Nearest to consists: congreso, mapping, adjacent, entities, nameable, representatives, represent, imagesize,
# Nearest to account: suspicions, smyrnaeans, decalogue, saboteur, nectar, fullness, frankenheimer, ipkf,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9996 0.3920 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9933 0.3907 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9751 0.3886 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0090 0.3881 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0251 0.3930 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9308 0.3845 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0262 0.3870 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0016 0.3874 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0069 0.3866 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0001 0.3848 sec/batch
# Nearest to and: the, in, of, a, as, corporatocracy, older, doosra,
# Nearest to with: writable, goalkeeper, in, never, intervened, expire, at, grandma,
# Nearest to at: semester, attended, enamoured, procession, chill, hundred, undertaking, flattered,
# Nearest to five: one, seven, two, three, four, eight, six, nine,
# Nearest to also: synonymously, barony, famille, propositional, sensitive, new, headline, positive,
# Nearest to than: blazon, formatted, more, their, costs, so, are, undertaking,
# Nearest to all: in, identify, lyceum, a, declare, sparingly, prod, serie,
# Nearest to there: milking, recalcitrant, number, atheistic, with, geocaches, engrailed, backronym,
# Nearest to running: ste, door, cardboard, willis, turpin, isuzu, regrouped, beazley,
# Nearest to applied: inductors, fredric, relativism, acknowledging, exptime, deist, halides, trustees,
# Nearest to taking: zealander, negated, beaten, humiliation, tori, razed, ocampo, modernizing,
# Nearest to know: you, we, bentine, why, dominatrixes, abracadabra, please, gbase,
# Nearest to universe: maranh, world, hermeneutics, sibm, discovered, bmws, neptunian, probabilities,
# Nearest to prince: order, giantesses, viii, fiorentino, eldest, hosea, westphalian, died,
# Nearest to consists: congreso, mapping, adjacent, entities, represent, auxerre, danville, democratic,
# Nearest to account: suspicions, smyrnaeans, fullness, nectar, ipkf, saboteur, decalogue, frankenheimer,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9784 0.3905 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9847 0.3872 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9990 0.3927 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0104 0.3850 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0194 0.3864 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0200 0.3863 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9994 0.3883 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9648 0.3890 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9740 0.3866 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0322 0.3888 sec/batch
# Nearest to and: the, of, in, eastern, a, corporatocracy, as, from,
# Nearest to with: writable, intervened, in, infighting, hospitalization, much, expire, however,
# Nearest to at: semester, enamoured, hundred, attended, chill, undertaking, procession, in,
# Nearest to five: one, two, seven, three, four, six, eight, zero,
# Nearest to also: synonymously, barony, propositional, new, headline, lethality, sensitive, famille,
# Nearest to than: blazon, so, are, more, costs, their, soak, undertaking,
# Nearest to all: in, sparingly, identify, lyceum, serie, prod, declare, prelog,
# Nearest to there: milking, number, atheistic, with, clerical, no, geocaches, fonni,
# Nearest to running: modifications, ste, door, willis, regrouped, cardboard, turpin, rajya,
# Nearest to applied: fredric, inductors, acknowledging, relativism, exptime, deist, trustees, halides,
# Nearest to taking: zealander, beaten, negated, humiliation, tori, modernizing, razed, minimise,
# Nearest to know: you, we, why, dominatrixes, gbase, abracadabra, needs, thank,
# Nearest to universe: maranh, world, hermeneutics, bmws, neptunian, berger, galactic, stellar,
# Nearest to prince: order, giantesses, fiorentino, eldest, viii, hosea, westphalian, died,
# ...
# Nearest to know: we, you, why, i, want, thank, if, nothing,
# Nearest to universe: maranh, photons, cosmic, gluon, questions, cosmos, nucleosynthesis, tain,
# Nearest to prince: giantesses, regnant, crown, order, fiorentino, devious, maxtor, hint,
# Nearest to consists: congreso, represent, stokely, or, artefact, nameable, ministers, pba,
# Nearest to account: smyrnaeans, ipkf, vecchi, fermat, fullness, equalled, companionate, nectar,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8699 0.3907 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7610 0.3846 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8356 0.3843 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8263 0.3856 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8121 0.3855 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8506 0.3875 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8762 0.3882 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8182 0.3836 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8874 0.3870 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8882 0.3869 sec/batch
# Nearest to and: the, of, in, a, as, by, with, to,
# Nearest to with: and, in, a, for, at, the, to, even,
# Nearest to at: with, in, a, enamoured, an, hundred, attended, to,
# Nearest to five: one, seven, two, three, four, six, zero, eight,
# Nearest to also: a, in, of, for, the, other, to, has,
# Nearest to than: less, more, are, soak, sizes, blazon, so, but,
# Nearest to all: in, a, are, the, to, of, there, and,
# Nearest to there: number, no, are, all, have, that, has, and,
# Nearest to running: regrouped, turpin, coach, gbagbo, erasable, modifications, beaten, rebranding,
# Nearest to applied: inductors, fredric, technology, genesis, deist, trustees, relativism, topics,
# Nearest to taking: zealander, ardour, modernizing, unpleasant, negated, soon, slaughter, prolong,
# Nearest to know: we, you, why, i, want, think, nothing, if,
# Nearest to universe: maranh, photons, cosmic, tain, venture, world, cosmos, questions,
# Nearest to prince: giantesses, regnant, denmark, maxtor, fiorentino, hint, itv, nova,
# Nearest to consists: congreso, represent, or, stokely, artefact, has, nameable, primus,
# Nearest to account: ipkf, smyrnaeans, vecchi, fermat, fullness, frankenheimer, milgrom, egregious,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8265 0.3907 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8472 0.3863 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8431 0.3894 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8579 0.3834 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8411 0.3843 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8452 0.3868 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8730 0.3884 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8355 0.3883 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8761 0.3872 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8407 0.3897 sec/batch
# Nearest to and: the, in, of, a, as, by, with, from,
# Nearest to with: in, and, a, even, for, to, however, the,
# Nearest to at: in, a, hundred, with, an, enamoured, attended, from,
# Nearest to five: one, two, three, seven, six, four, zero, eight,
# Nearest to also: a, of, for, in, the, other, to, has,
# Nearest to than: more, less, are, sizes, but, so, soak, blazon,
# Nearest to all: in, a, are, the, to, of, and, there,
# Nearest to there: number, no, one, all, that, and, are, have,
# Nearest to running: regrouped, gbagbo, turpin, coach, modifications, erasable, rebranding, garber,
# Nearest to applied: inductors, fredric, genesis, specificities, relativism, trustees, halides, technology,
# Nearest to taking: zealander, modernizing, ardour, negated, unpleasant, soon, atheroma, slaughter,
# Nearest to know: we, you, why, i, want, nothing, thank, think,
# Nearest to universe: maranh, photons, cosmic, world, cosmos, questions, gluon, venture,
# Nearest to prince: crown, giantesses, empress, regnant, order, abdicated, fiorentino, denmark,
# Nearest to consists: congreso, represent, artefact, or, stokely, has, parodying, pba,
# Nearest to account: vecchi, ipkf, fermat, smyrnaeans, fullness, frankenheimer, milgrom, arcseconds,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8561 0.3898 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8497 0.3914 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8297 0.3882 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8326 0.3862 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8805 0.3878 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8468 0.3907 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9675 0.3893 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8879 0.3890 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8993 0.3885 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8424 0.3894 sec/batch
# Nearest to and: in, the, of, a, by, as, with, for,
# Nearest to with: in, and, a, even, for, to, however, at,
# Nearest to at: in, attended, hundred, with, enamoured, born, an, procession,
# Nearest to five: one, two, three, seven, zero, six, four, eight,
# Nearest to also: of, a, for, in, other, the, and, has,
# Nearest to than: less, more, sizes, are, so, soak, but, blazon,
# Nearest to all: a, in, are, the, to, and, there, both,
# Nearest to there: number, no, one, have, that, are, far, in,
# Nearest to running: regrouped, gbagbo, turpin, coach, modifications, garber, erasable, rajya,
# Nearest to applied: inductors, fredric, technology, argumentation, relativism, specificities, deist, dilation,
# Nearest to taking: zealander, ardour, negated, modernizing, atheroma, ruickbie, unpleasant, dissociate,
# Nearest to know: you, we, why, i, want, thank, think, nothing,
# Nearest to universe: maranh, photons, cosmic, world, cosmos, venture, gluon, questions,
# Nearest to prince: order, crown, giantesses, regnant, empress, maxtor, fiorentino, devious,
# Nearest to consists: congreso, represent, or, stokely, inflexible, artefact, pba, has,
# Nearest to account: vecchi, ipkf, fullness, fermat, smyrnaeans, demonstrates, frankenheimer, industrialization,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7930 0.3886 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8677 0.3889 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7891 0.3897 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8836 0.3886 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8307 0.3889 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8460 0.3875 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8947 0.2212 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8387 0.3880 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8635 0.3902 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8498 0.3864 sec/batch
# Nearest to and: the, in, of, a, as, by, with, to,
# Nearest to with: in, and, a, even, to, at, the, however,
# Nearest to at: in, with, the, a, from, attended, hundred, was,
# Nearest to five: one, two, seven, three, six, four, zero, eight,
# Nearest to also: of, a, in, other, for, the, and, to,
# Nearest to than: less, more, soak, sizes, so, are, but, higher,
# Nearest to all: in, a, the, are, there, and, of, to,
# Nearest to there: no, that, have, number, all, are, only, non,
# Nearest to running: regrouped, gbagbo, turpin, coach, rajya, modifications, rebranding, eurocard,
# Nearest to applied: inductors, fredric, argumentation, relativism, halides, technology, topics, genesis,
# Nearest to taking: zealander, modernizing, ardour, came, negated, unpleasant, soon, atheroma,
# Nearest to know: you, we, why, i, want, think, thank, nothing,
# Nearest to universe: maranh, photons, cosmic, gluon, cosmos, questions, venture, artificially,
# Nearest to prince: giantesses, crown, empress, regnant, order, devious, denmark, abdicated,
# Nearest to consists: congreso, represent, stokely, artefact, or, inflexible, pba, parodying,
# Nearest to account: vecchi, ipkf, demonstrates, fermat, frankenheimer, smyrnaeans, companionate, fullness,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8272 0.3882 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8298 0.3843 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8290 0.3879 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7876 0.3880 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8427 0.3882 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8273 0.3862 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8706 0.3872 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7631 0.3869 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8200 0.3871 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7926 0.3852 sec/batch
# Nearest to and: the, in, of, a, as, by, for, with,
# Nearest to with: and, in, a, the, at, to, for, even,
# Nearest to at: with, in, a, the, hundred, up, an, attended,
# Nearest to five: one, two, three, seven, six, zero, four, nine,
# Nearest to also: a, of, in, other, for, to, the, and,
# Nearest to than: more, less, but, so, are, soak, sizes, become,
# Nearest to all: a, in, are, the, to, there, and, of,
# Nearest to there: number, no, that, all, one, have, are, to,
# Nearest to running: regrouped, gbagbo, coach, modifications, rajya, eurocard, turpin, erasable,
# Nearest to applied: inductors, fredric, topics, argumentation, relativism, halides, lapis, technology,
# Nearest to taking: zealander, ardour, negated, atheroma, modernizing, came, ruickbie, soon,
# Nearest to know: we, you, why, i, want, think, nothing, thank,
# Nearest to universe: maranh, photons, gluon, questions, cosmic, artificially, cosmos, empirical,
# Nearest to prince: giantesses, regnant, maxtor, order, crown, hint, devious, empress,
# Nearest to consists: congreso, represent, has, separate, artefact, stokely, or, inflexible,
# Nearest to account: vecchi, ipkf, demonstrates, smyrnaeans, milgrom, egregious, fermat, massless,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7630 0.3900 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8205 0.3893 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8535 0.3904 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8196 0.3887 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8284 0.3848 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9040 0.3877 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8258 0.3887 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8257 0.3864 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8412 0.3860 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8514 0.3896 sec/batch
# Nearest to and: the, in, of, a, as, by, to, with,
# Nearest to with: and, in, a, the, for, at, to, as,
# Nearest to at: with, in, a, the, an, to, and, every,
# Nearest to five: one, two, three, zero, seven, six, four, nine,
# Nearest to also: a, of, in, for, other, and, to, the,
# Nearest to than: more, less, sizes, so, are, but, soak, as,
# Nearest to all: a, in, are, the, to, there, and, of,
# Nearest to there: number, one, all, no, that, have, are, in,
# Nearest to running: gbagbo, regrouped, coach, rajya, turpin, modifications, erasable, eurocard,
# Nearest to applied: inductors, fredric, specificities, topics, argumentation, genesis, relativism, business,
# Nearest to taking: zealander, ardour, negated, modernizing, atheroma, ruickbie, soon, unpleasant,
# Nearest to know: you, we, why, i, want, nothing, vous, think,
# Nearest to universe: maranh, photons, gluon, artificially, rampaging, cosmic, venture, questions,
# Nearest to prince: giantesses, crown, empress, regnant, order, clan, princess, hint,
# Nearest to consists: congreso, has, represent, stokely, inflexible, or, artefact, branch,
# Nearest to account: vecchi, ipkf, demonstrates, equalled, accounted, egregious, solar, milgrom,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8449 0.3902 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8356 0.3861 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7996 0.3870 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8358 0.3874 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8983 0.3854 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8614 0.3929 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8300 0.3862 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8353 0.3888 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8212 0.3904 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7911 0.3897 sec/batch
# Nearest to and: the, in, of, a, as, to, by, with,
# Nearest to with: and, in, a, for, to, even, however, the,
# Nearest to at: in, with, from, the, to, three, hundred, two,
# Nearest to five: one, two, three, zero, six, four, seven, nine,
# Nearest to also: of, a, other, in, for, the, and, to,
# Nearest to than: less, more, are, sizes, so, but, soak, have,
# Nearest to all: a, in, are, to, the, and, of, there,
# Nearest to there: have, number, no, that, one, are, is, and,
# Nearest to running: gbagbo, rajya, regrouped, coach, erasable, modifications, eurocard, turpin,
# Nearest to applied: inductors, fredric, genesis, argumentation, specificities, halides, topics, relativism,
# Nearest to taking: zealander, negated, ardour, modernizing, ruickbie, atheroma, came, soon,
# Nearest to know: you, we, why, i, want, vous, nothing, think,
# Nearest to universe: maranh, photons, gluon, rampaging, cosmic, sparky, bmws, cosmos,
# Nearest to prince: crown, giantesses, regnant, empress, order, maxtor, princess, denmark,
# Nearest to consists: congreso, has, represent, stokely, artefact, parodying, inflexible, or,
# Nearest to account: vecchi, demonstrates, ipkf, accounts, accounted, massless, apparitions, fermat,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8480 0.4281 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8260 0.4165 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9225 0.3993 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9389 0.3896 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8976 0.3810 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8324 0.3888 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7669 0.3934 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8575 0.3983 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7403 0.3980 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.9054 0.4042 sec/batch
# Nearest to and: the, in, of, a, as, to, by, with,
# Nearest to with: and, in, a, s, to, for, the, as,
# Nearest to at: s, in, attended, with, born, enamoured, from, the,
# Nearest to five: one, three, two, zero, six, seven, four, nine,
# Nearest to also: of, a, other, in, the, for, and, to,
# Nearest to than: less, more, sizes, are, soak, so, higher, have,
# Nearest to all: a, in, are, the, there, to, and, of,
# Nearest to there: have, are, that, number, no, all, in, is,
# Nearest to running: gbagbo, modifications, regrouped, rajya, coach, krav, erasable, turpin,
# Nearest to applied: inductors, fredric, topics, genesis, argumentation, halides, technology, specificities,
# Nearest to taking: zealander, ardour, modernizing, soon, atheroma, negated, ruickbie, indoors,
# Nearest to know: you, we, why, want, i, think, vous, thank,
# Nearest to universe: maranh, photons, rampaging, questions, sparky, venture, gluon, cosmos,
# Nearest to prince: giantesses, regnant, crown, maxtor, empress, devious, denmark, order,
# Nearest to consists: congreso, has, represent, branch, inflexible, or, stokely, artefact,
# Nearest to account: vecchi, demonstrates, ipkf, arcseconds, accounted, massless, frankenheimer, disarray,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8553 0.3872 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8601 0.4118 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
